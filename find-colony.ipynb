# %%
# !pip install ultralytics opencv-python numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

YAML_PATH='/kaggle/input/datasets/dannyahn/colony-counter/COLONY COUNTER.v3i.yolov11/data.yaml'
model = YOLO("yolo11n.pt")
model.train(data=str(YAML_PATH), task="detect", imgsz=1024, epochs=200, batch=16, device=[0,1])
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# ...
